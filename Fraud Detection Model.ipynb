# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# Load Sample UPI Transaction Data
df = pd.read_csv("/content/drive/My Drive/Major Project/Dataset/UPI_Fraud_Dataset.csv")  # Replace with actual dataset

# Display basic info
print("Dataset Summary:\n", df.info())
print("Missing Values:\n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction_ID               5000 non-null   int64
#  1   Sender_UPI_ID                5000 non-null   object
#  2   Receiver_UPI_ID              5000 non-null   object
#  3   Transaction_Amount           5000 non-null   float64
#  4   Transaction_Time             5000 non-null   object
#  5   Device_Type                  5000 non-null   object
#  6   IP_Change_Flag               5000 non-null   int64
#  7   Location_Change_Flag         5000 non-null   int64
#  8   Multiple_Quick_Transactions  5000 non-null   int64
#  9   Transaction_Fraud_Flag       5000 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 390.8+ KB
# Dataset Summary:
#  None
# Missing Values:
#  Transaction_ID                 0
# Sender_UPI_ID                  0
# Receiver_UPI_ID                0
# Transaction_Amount             0
# Transaction_Time               0
# Device_Type                    0
# IP_Change_Flag                 0
# Location_Change_Flag           0
# Multiple_Quick_Transactions    0
# Transaction_Fraud_Flag         0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from imblearn.over_sampling import SMOTE  # Handle class imbalance

# Load the dataset
df = pd.read_csv("/content/drive/My Drive/Major Project/Dataset/UPI_Fraud_Dataset.csv")

# Drop irrelevant columns (IDs are unique and not predictive)
df.drop(columns=["Transaction_ID", "Sender_UPI_ID", "Receiver_UPI_ID"], inplace=True)

# Handle missing values (fill numerical NaN with median)
df.fillna(df.median(numeric_only=True), inplace=True)

# Convert Transaction_Time to datetime format
df["Transaction_Time"] = pd.to_datetime(df["Transaction_Time"])

# Extract time-based features
df["Hour"] = df["Transaction_Time"].dt.hour  # Hour of transaction
df["Day"] = df["Transaction_Time"].dt.dayofweek  # Day of the week
df.drop(columns=["Transaction_Time"], inplace=True)  # Drop original timestamp

# Encode categorical column (Device_Type)
le = LabelEncoder()
df["Device_Type"] = le.fit_transform(df["Device_Type"])

# Define features (X) and target (y)
X = df.drop(columns=["Transaction_Fraud_Flag"]).values
y = df["Transaction_Fraud_Flag"].values

# Standardize numerical features (Transaction Amount)
scaler = StandardScaler()
X[:, 0] = scaler.fit_transform(X[:, 0].reshape(-1, 1)).flatten()  # Assuming Transaction_Amount is at index 0

# Handle class imbalance using SMOTE (only if dataset is imbalanced)
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Reshape for LSTM (samples, timesteps, features)
X_resampled = X_resampled.reshape((X_resampled.shape[0], 1, X_resampled.shape[1]))

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Build LSTM Model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(1, X_train.shape[2])),
    Dropout(0.2),
    LSTM(50),
    Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5025 - loss: 0.6932 - val_accuracy: 0.5605 - val_loss: 0.6876
# Epoch 2/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5555 - loss: 0.6867 - val_accuracy: 0.5589 - val_loss: 0.6855
# Epoch 3/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5640 - loss: 0.6818 - val_accuracy: 0.5737 - val_loss: 0.6781
# Epoch 4/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5621 - loss: 0.6757 - val_accuracy: 0.5800 - val_loss: 0.6730
# Epoch 5/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5740 - loss: 0.6741 - val_accuracy: 0.5947 - val_loss: 0.6670
# Epoch 6/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6014 - loss: 0.6598 - val_accuracy: 0.5832 - val_loss: 0.6691
# Epoch 7/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6026 - loss: 0.6574 - val_accuracy: 0.6174 - val_loss: 0.6582
# Epoch 8/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6030 - loss: 0.6594 - val_accuracy: 0.6163 - val_loss: 0.6564
# Epoch 9/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6090 - loss: 0.6599 - val_accuracy: 0.6232 - val_loss: 0.6529
# Epoch 10/10
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6086 - loss: 0.6576 - val_accuracy: 0.6200 - val_loss: 0.6508

# %%
# Convert back to DataFrame for saving
df_resampled = pd.DataFrame(X_resampled.reshape(X_resampled.shape[0], X_resampled.shape[2]), columns=df.drop(columns=["Transaction_Fraud_Flag"]).columns)
df_resampled["Transaction_Fraud_Flag"] = y_resampled  # Add target column back

# Save to CSV
df_resampled.to_csv("/content/drive/My Drive/Major Project/Dataset/UPI_Fraud_Preprocessed.csv", index=False)

print("Preprocessed dataset saved successfully!")
# Out:
# Preprocessed dataset saved successfully!

# %%
model.save("/content/drive/My Drive/Major Project/Models/upi_fraud_lstm_model_final.h5")

print("Deep Learning Model Trained and Saved as 'upi_fraud_lstm_model_final.h5'.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Deep Learning Model Trained and Saved as 'upi_fraud_lstm_model_final.h5'.

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6251 - loss: 0.6495
# Test Accuracy: 0.6200

# %%
import numpy as np

# Example new transaction (ensure it has 7 features)
new_transaction = np.array([[5000, 1, 0, 1, 15, 2, 1]])  # Modify values as needed

# Standardize numerical features (Transaction_Amount is at index 0)
new_transaction[:, 0] = scaler.transform(new_transaction[:, 0].reshape(-1, 1)).flatten()

# Reshape for LSTM (samples, timesteps, features)
new_transaction_reshaped = new_transaction.reshape((1, 1, new_transaction.shape[1]))

# Make prediction
prediction = model.predict(new_transaction_reshaped)

# Extract fraud probability
fraud_probability = prediction[0][0]

# Print result
if fraud_probability > 0.5:
    print(f"🚨 ALERT: Possible Fraud! (Confidence: {fraud_probability:.2%})")
else:
    print(f"✅ Safe Transaction (Confidence: {(1 - fraud_probability):.2%})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# ✅ Safe Transaction (Confidence: 99.98%)

# %%
import numpy as np

# Example fraudulent transaction (scaled and preprocessed)
new_transaction = np.array([[1.042724982, 0, 0, 0, 0, 0, 0, 1]])

# Remove the fraud label (last column) to match model input shape
new_transaction = new_transaction[:, :-1]

# Reshape for LSTM model (samples=1, timesteps=1, features=7)
new_transaction_reshaped = new_transaction.reshape((1, 1, new_transaction.shape[1]))

# Predict fraud probability
fraud_probability = model.predict(new_transaction_reshaped)[0][0]

# Interpret the prediction
threshold = 0.5  # Standard fraud detection threshold
if fraud_probability >= threshold:
    print(f"⚠️ Fraudulent Transaction Detected! (Confidence: {fraud_probability * 100:.2f}%)")
else:
    print(f"✅ Safe Transaction (Confidence: {100 - fraud_probability * 100:.2f}%)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# ✅ Safe Transaction (Confidence: 56.44%)

# %%
# Get predictions for test data
y_pred_prob = model.predict(X_test)
y_pred_labels = (y_pred_prob >= 0.5).astype(int)

# Check fraud classification accuracy
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_labels))
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.51      0.57       945
#            1       0.60      0.73      0.66       955
#
#     accuracy                           0.62      1900
#    macro avg       0.63      0.62      0.62      1900
# weighted avg       0.63      0.62      0.62      1900

# %%
import pandas as pd

# Load preprocessed dataset
df_preprocessed = pd.read_csv("/content/drive/My Drive/Major Project/Dataset/UPI_Fraud_Preprocessed.csv")

# Extract fraudulent transactions
fraudulent_transactions = df_preprocessed[df_preprocessed["Transaction_Fraud_Flag"] == 1]
fraudulent_features = fraudulent_transactions.drop(columns=["Transaction_Fraud_Flag"]).values

# Reshape for LSTM
fraudulent_features_reshaped = fraudulent_features.reshape((fraudulent_features.shape[0], 1, fraudulent_features.shape[1]))

print(f"Fraudulent Transactions Shape: {fraudulent_features_reshaped.shape}")
# Out:
# Fraudulent Transactions Shape: (4749, 1, 7)

# %%
# Make predictions
fraud_predictions = model.predict(fraudulent_features_reshaped)

# Convert predictions to fraud probabilities
fraud_probabilities = fraud_predictions.flatten()

# Display results
for i, prob in enumerate(fraud_probabilities):
    print(f"Transaction {i+1}: Fraud Probability: {prob*100:.2f}%")
# Out:
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Transaction 1: Fraud Probability: 43.56%
# Transaction 2: Fraud Probability: 55.79%
# Transaction 3: Fraud Probability: 51.50%
# Transaction 4: Fraud Probability: 52.84%
# Transaction 5: Fraud Probability: 61.02%
# Transaction 6: Fraud Probability: 30.30%
# Transaction 7: Fraud Probability: 6.08%
# Transaction 8: Fraud Probability: 63.24%
# Transaction 9: Fraud Probability: 15.79%
# Transaction 10: Fraud Probability: 34.89%
# Transaction 11: Fraud Probability: 10.88%
# Transaction 12: Fraud Probability: 55.72%
# Transaction 13: Fraud Probability: 11.89%
# Transaction 14: Fraud Probability: 40.41%
# Transaction 15: Fraud Probability: 33.18%
# Transaction 16: Fraud Probability: 34.79%
# Transaction 17: Fraud Probability: 40.39%
# Transaction 18: Fraud Probability: 55.83%
# Transaction 19: Fraud Probability: 59.07%
# Transaction 20: Fraud Probability: 45.21%
# Transaction 21: Fraud Probability: 43.89%
# Transaction 22: Fraud Probability: 41.13%
# Transaction 23: Fraud Probability: 44.37%
# Transaction 24: Fraud Probability: 45.74%
# Transaction 25: Fraud Probability: 45.77%
# Transaction 26: Fraud Probability: 23.78%
# Transaction 27: Fraud Probability: 45.98%
# Transaction 28: Fraud Probability: 42.37%
# Transaction 29: Fraud Probability: 55.21%
# Transaction 30: Fraud Probability: 48.26%
# Transaction 31: Fraud Probability: 52.03%
# Transaction 32: Fraud Probability: 55.87%
# Transaction 33: Fraud Probability: 43.93%
# Transaction 34: Fraud Probability: 43.73%
# Transaction 35: Fraud Probability: 52.65%
# Transaction 36: Fraud Probability: 49.51%
# Transaction 37: Fraud Probability: 55.20%
# Transaction 38: Fraud Probability: 28.99%
# Transaction 39: Fraud Probability: 53.92%
# Transaction 40: Fraud Probability: 52.80%
# Transaction 41: Fraud Probability: 54.35%
# Transaction 42: Fraud Probability: 51.66%
# Transaction 43: Fraud Probability: 54.01%
# Transaction 44: Fraud Probability: 47.88%
# Transaction 45: Fraud Probability: 61.83%
# Transaction 46: Fraud Probability: 58.75%
# Transaction 47: Fraud Probability: 41.54%
# Transaction 48: Fraud Probability: 55.01%
# Transaction 49: Fraud Probability: 42.81%
# Transaction 50: Fraud Probability: 52.50%
# Transaction 51: Fraud Probability: 38.05%
# Transaction 52: Fraud Probability: 40.65%
# Transaction 53: Fraud Probability: 56.27%
# Transaction 54: Fraud Probability: 54.34%
# Transaction 55: Fraud Probability: 53.45%
# Transaction 56: Fraud Probability: 57.96%
# Transaction 57: Fraud Probability: 40.36%
# Transaction 58: Fraud Probability: 54.27%
# Transaction 59: Fraud Probability: 55.66%
# Transaction 60: Fraud Probability: 64.53%
# Transaction 61: Fraud Probability: 51.00%
# Transaction 62: Fraud Probability: 42.11%
# Transaction 63: Fraud Probability: 65.37%
# Transaction 64: Fraud Probability: 32.92%
# Transaction 65: Fraud Probability: 67.30%
# Transaction 66: Fraud Probability: 50.05%
# Transaction 67: Fraud Probability: 68.81%
# Transaction 68: Fraud Probability: 63.36%
# Transaction 69: Fraud Probability: 68.89%
# Transaction 70: Fraud Probability: 57.23%
# Transaction 71: Fraud Probability: 59.81%
# Transaction 72: Fraud Probability: 59.74%
# Transaction 73: Fraud Probability: 49.89%
# Transaction 74: Fraud Probability: 68.55%
# Transaction 75: Fraud Probability: 60.29%
# Transaction 76: Fraud Probability: 60.29%
# Transaction 77: Fraud Probability: 45.06%
# Transaction 78: Fraud Probability: 50.45%
# Transaction 79: Fraud Probability: 66.78%
# Transaction 80: Fraud Probability: 59.22%
# Transaction 81: Fraud Probability: 62.53%
# Transaction 82: Fraud Probability: 49.15%
# Transaction 83: Fraud Probability: 61.78%
# Transaction 84: Fraud Probability: 70.13%
# Transaction 85: Fraud Probability: 55.64%
# Transaction 86: Fraud Probability: 60.38%
# Transaction 87: Fraud Probability: 53.97%
# Transaction 88: Fraud Probability: 58.08%
# Transaction 89: Fraud Probability: 53.33%
# Transaction 90: Fraud Probability: 70.15%
# Transaction 91: Fraud Probability: 59.27%
# Transaction 92: Fraud Probability: 65.12%
# Transaction 93: Fraud Probability: 68.58%
# Transaction 94: Fraud Probability: 66.17%
# Transaction 95: Fraud Probability: 62.41%
# Transaction 96: Fraud Probability: 50.85%
# Transaction 97: Fraud Probability: 63.76%
# Transaction 98: Fraud Probability: 65.28%
# Transaction 99: Fraud Probability: 53.91%
# Transaction 100: Fraud Probability: 58.94%
# Transaction 101: Fraud Probability: 68.55%
# Transaction 102: Fraud Probability: 64.16%
# Transaction 103: Fraud Probability: 47.05%
# Transaction 104: Fraud Probability: 64.93%
# Transaction 105: Fraud Probability: 63.01%
# Transaction 106: Fraud Probability: 46.62%
# Transaction 107: Fraud Probability: 12.70%
# Transaction 108: Fraud Probability: 55.63%
# Transaction 109: Fraud Probability: 64.69%
# Transaction 110: Fraud Probability: 57.76%
# Transaction 111: Fraud Probability: 63.22%
# Transaction 112: Fraud Probability: 62.22%
# Transaction 113: Fraud Probability: 64.19%
# Transaction 114: Fraud Probability: 48.51%
# Transaction 115: Fraud Probability: 62.95%
# Transaction 116: Fraud Probability: 61.90%
# Transaction 117: Fraud Probability: 54.02%
# Transaction 118: Fraud Probability: 59.73%
# Transaction 119: Fraud Probability: 46.54%
# Transaction 120: Fraud Probability: 57.50%
# Transaction 121: Fraud Probability: 60.54%
# Transaction 122: Fraud Probability: 61.55%
# Transaction 123: Fraud Probability: 55.56%
# Transaction 124: Fraud Probability: 55.06%
# Transaction 125: Fraud Probability: 56.54%
# Transaction 126: Fraud Probability: 59.85%
# Transaction 127: Fraud Probability: 52.67%
# Transaction 128: Fraud Probability: 53.67%
# Transaction 129: Fraud Probability: 58.41%
# Transaction 130: Fraud Probability: 54.46%
# Transaction 131: Fraud Probability: 54.56%
# Transaction 132: Fraud Probability: 60.36%
# Transaction 133: Fraud Probability: 54.55%
# Transaction 134: Fraud Probability: 61.35%
# Transaction 135: Fraud Probability: 61.09%
# Transaction 136: Fraud Probability: 57.15%
# Transaction 137: Fraud Probability: 48.98%
# Transaction 138: Fraud Probability: 57.21%
# Transaction 139: Fraud Probability: 42.10%
# Transaction 140: Fraud Probability: 64.01%
# Transaction 141: Fraud Probability: 59.49%
# Transaction 142: Fraud Probability: 63.96%
# Transaction 143: Fraud Probability: 51.31%
# Transaction 144: Fraud Probability: 47.16%
# Transaction 145: Fraud Probability: 73.49%
# Transaction 146: Fraud Probability: 42.93%
# Transaction 147: Fraud Probability: 52.19%
# Transaction 148: Fraud Probability: 60.17%
# Transaction 149: Fraud Probability: 49.94%
# Transaction 150: Fraud Probability: 48.15%
# Transaction 151: Fraud Probability: 59.48%
# Transaction 152: Fraud Probability: 53.33%
# Transaction 153: Fraud Probability: 57.65%
# Transaction 154: Fraud Probability: 53.88%
# Transaction 155: Fraud Probability: 27.30%
# Transaction 156: Fraud Probability: 39.88%
# Transaction 157: Fraud Probability: 47.56%
# Transaction 158: Fraud Probability: 69.19%
# Transaction 159: Fraud Probability: 47.04%
# Transaction 160: Fraud Probability: 40.06%
# Transaction 161: Fraud Probability: 73.79%
# Transaction 162: Fraud Probability: 51.47%
# Transaction 163: Fraud Probability: 56.02%
# Transaction 164: Fraud Probability: 58.44%
# Transaction 165: Fraud Probability: 53.88%
# Transaction 166: Fraud Probability: 54.32%
# Transaction 167: Fraud Probability: 73.95%
# Transaction 168: Fraud Probability: 43.95%
# Transaction 169: Fraud Probability: 58.17%
# Transaction 170: Fraud Probability: 62.02%
# Transaction 171: Fraud Probability: 60.50%
# Transaction 172: Fraud Probability: 51.57%
# Transaction 173: Fraud Probability: 57.19%
# Transaction 174: Fraud Probability: 63.59%
# Transaction 175: Fraud Probability: 64.08%
# Transaction 176: Fraud Probability: 46.85%
# Transaction 177: Fraud Probability: 51.49%
# Transaction 178: Fraud Probability: 56.28%
# Transaction 179: Fraud Probability: 56.64%
# Transaction 180: Fraud Probability: 58.85%
# Transaction 181: Fraud Probability: 26.22%
# Transaction 182: Fraud Probability: 74.67%
# Transaction 183: Fraud Probability: 59.66%
# Transaction 184: Fraud Probability: 60.12%
# Transaction 185: Fraud Probability: 65.48%
# Transaction 186: Fraud Probability: 48.80%
# Transaction 187: Fraud Probability: 46.59%
# Transaction 188: Fraud Probability: 73.79%
# Transaction 189: Fraud Probability: 55.26%
# Transaction 190: Fraud Probability: 56.37%
# Transaction 191: Fraud Probability: 47.44%
# Transaction 192: Fraud Probability: 46.06%
# Transaction 193: Fraud Probability: 60.04%
# Transaction 194: Fraud Probability: 48.98%
# Transaction 195: Fraud Probability: 58.57%
# Transaction 196: Fraud Probability: 59.63%
# Transaction 197: Fraud Probability: 56.46%
# Transaction 198: Fraud Probability: 60.85%
# Transaction 199: Fraud Probability: 58.62%
# Transaction 200: Fraud Probability: 45.98%
# Transaction 201: Fraud Probability: 64.63%
# Transaction 202: Fraud Probability: 58.63%
# Transaction 203: Fraud Probability: 42.98%
# Transaction 204: Fraud Probability: 52.83%
# Transaction 205: Fraud Probability: 44.44%
# Transaction 206: Fraud Probability: 55.81%
# Transaction 207: Fraud Probability: 45.66%
# Transaction 208: Fraud Probability: 57.70%
# Transaction 209: Fraud Probability: 57.69%
# Transaction 210: Fraud Probability: 51.03%
# Transaction 211: Fraud Probability: 45.35%
# Transaction 212: Fraud Probability: 42.87%
# Transaction 213: Fraud Probability: 57.83%
# Transaction 214: Fraud Probability: 51.00%
# Transaction 215: Fraud Probability: 52.86%
# Transaction 216: Fraud Probability: 55.99%
# Transaction 217: Fraud Probability: 58.11%
# Transaction 218: Fraud Probability: 51.52%
# Transaction 219: Fraud Probability: 56.22%
# Transaction 220: Fraud Probability: 48.06%
# Transaction 221: Fraud Probability: 49.95%
# Transaction 222: Fraud Probability: 68.75%
# Transaction 223: Fraud Probability: 56.43%
# Transaction 224: Fraud Probability: 56.99%
# Transaction 225: Fraud Probability: 28.22%
# Transaction 226: Fraud Probability: 45.32%
# Transaction 227: Fraud Probability: 52.98%
# Transaction 228: Fraud Probability: 45.89%
# Transaction 229: Fraud Probability: 47.40%
# Transaction 230: Fraud Probability: 38.33%
# Transaction 231: Fraud Probability: 38.12%
# Transaction 232: Fraud Probability: 42.57%
# Transaction 233: Fraud Probability: 39.93%
# Transaction 234: Fraud Probability: 33.63%
# Transaction 235: Fraud Probability: 42.93%
# Transaction 236: Fraud Probability: 45.04%
# Transaction 237: Fraud Probability: 44.77%
# Transaction 238: Fraud Probability: 50.15%
# Transaction 239: Fraud Probability: 43.77%
# Transaction 240: Fraud Probability: 49.66%
# Transaction 241: Fraud Probability: 49.24%
# Transaction 242: Fraud Probability: 49.92%
# Transaction 243: Fraud Probability: 43.86%
# Transaction 244: Fraud Probability: 37.59%
# Transaction 245: Fraud Probability: 38.88%
# Transaction 246: Fraud Probability: 49.68%
# Transaction 247: Fraud Probability: 49.49%
# Transaction 248: Fraud Probability: 50.99%
# Transaction 249: Fraud Probability: 56.39%
# Transaction 250: Fraud Probability: 47.38%
# Transaction 251: Fraud Probability: 47.78%
# Transaction 252: Fraud Probability: 46.91%
# Transaction 253: Fraud Probability: 55.49%
# Transaction 254: Fraud Probability: 55.76%
# Transaction 255: Fraud Probability: 57.52%
# Transaction 256: Fraud Probability: 63.18%
# Transaction 257: Fraud Probability: 45.95%
# Transaction 258: Fraud Probability: 66.11%
# Transaction 259: Fraud Probability: 51.16%
# Transaction 260: Fraud Probability: 68.89%
# Transaction 261: Fraud Probability: 57.55%
# Transaction 262: Fraud Probability: 40.29%
# Transaction 263: Fraud Probability: 67.06%
# Transaction 264: Fraud Probability: 45.83%
# Transaction 265: Fraud Probability: 56.49%
# Transaction 266: Fraud Probability: 57.81%
# Transaction 267: Fraud Probability: 53.10%
# Transaction 268: Fraud Probability: 73.74%
# Transaction 269: Fraud Probability: 37.89%
# Transaction 270: Fraud Probability: 47.71%
# Transaction 271: Fraud Probability: 56.91%
# Transaction 272: Fraud Probability: 49.83%
# Transaction 273: Fraud Probability: 51.69%
# Transaction 274: Fraud Probability: 69.00%
# Transaction 275: Fraud Probability: 61.85%
# Transaction 276: Fraud Probability: 48.54%
# Transaction 277: Fraud Probability: 49.29%
# Transaction 278: Fraud Probability: 61.31%
# Transaction 279: Fraud Probability: 56.30%
# Transaction 280: Fraud Probability: 47.52%
# Transaction 281: Fraud Probability: 62.15%
# Transaction 282: Fraud Probability: 59.70%
# Transaction 283: Fraud Probability: 54.36%
# Transaction 284: Fraud Probability: 59.94%
# Transaction 285: Fraud Probability: 55.19%
# Transaction 286: Fraud Probability: 51.14%
# Transaction 287: Fraud Probability: 64.11%
# Transaction 288: Fraud Probability: 68.37%
# Transaction 289: Fraud Probability: 38.73%
# Transaction 290: Fraud Probability: 54.18%
# Transaction 291: Fraud Probability: 68.96%
# Transaction 292: Fraud Probability: 62.70%
# Transaction 293: Fraud Probability: 50.08%
# Transaction 294: Fraud Probability: 65.66%
# Transaction 295: Fraud Probability: 61.51%
# Transaction 296: Fraud Probability: 33.49%
# Transaction 297: Fraud Probability: 54.22%
# Transaction 298: Fraud Probability: 44.73%
# Transaction 299: Fraud Probability: 39.99%
# Transaction 300: Fraud Probability: 64.37%
# Transaction 301: Fraud Probability: 65.76%
# Transaction 302: Fraud Probability: 57.42%
# Transaction 303: Fraud Probability: 47.70%
# Transaction 304: Fraud Probability: 63.83%
# Transaction 305: Fraud Probability: 39.29%
# Transaction 306: Fraud Probability: 33.03%
# Transaction 307: Fraud Probability: 48.95%
# Transaction 308: Fraud Probability: 37.26%
# Transaction 309: Fraud Probability: 60.40%
# Transaction 310: Fraud Probability: 45.76%
# Transaction 311: Fraud Probability: 62.31%
# Transaction 312: Fraud Probability: 38.96%
# Transaction 313: Fraud Probability: 59.86%
# Transaction 314: Fraud Probability: 62.55%
# Transaction 315: Fraud Probability: 44.39%
# Transaction 316: Fraud Probability: 61.57%
# Transaction 317: Fraud Probability: 47.36%
# Transaction 318: Fraud Probability: 44.60%
# Transaction 319: Fraud Probability: 55.60%
# Transaction 320: Fraud Probability: 66.57%
# Transaction 321: Fraud Probability: 68.35%
# Transaction 322: Fraud Probability: 53.45%
# Transaction 323: Fraud Probability: 65.12%
# Transaction 324: Fraud Probability: 48.48%
# Transaction 325: Fraud Probability: 60.87%
# Transaction 326: Fraud Probability: 48.61%
# Transaction 327: Fraud Probability: 54.67%
# Transaction 328: Fraud Probability: 45.04%
# Transaction 329: Fraud Probability: 61.94%
# Transaction 330: Fraud Probability: 58.92%
# Transaction 331: Fraud Probability: 51.23%
# Transaction 332: Fraud Probability: 62.24%
# Transaction 333: Fraud Probability: 55.72%
# Transaction 334: Fraud Probability: 56.87%
# Transaction 335: Fraud Probability: 45.00%
# Transaction 336: Fraud Probability: 69.16%
# Transaction 337: Fraud Probability: 46.03%
# Transaction 338: Fraud Probability: 63.28%
# Transaction 339: Fraud Probability: 37.86%
# Transaction 340: Fraud Probability: 57.01%
# Transaction 341: Fraud Probability: 55.45%
# Transaction 342: Fraud Probability: 39.44%
# Transaction 343: Fraud Probability: 61.83%
# Transaction 344: Fraud Probability: 62.79%
# Transaction 345: Fraud Probability: 44.11%
# Transaction 346: Fraud Probability: 56.01%
# Transaction 347: Fraud Probability: 65.05%
# Transaction 348: Fraud Probability: 46.22%
# Transaction 349: Fraud Probability: 61.71%
# Transaction 350: Fraud Probability: 33.63%
# Transaction 351: Fraud Probability: 48.83%
# Transaction 352: Fraud Probability: 46.01%
# Transaction 353: Fraud Probability: 54.00%
# Transaction 354: Fraud Probability: 38.97%
# Transaction 355: Fraud Probability: 50.06%
# Transaction 356: Fraud Probability: 50.35%
# Transaction 357: Fraud Probability: 53.21%
# Transaction 358: Fraud Probability: 67.94%
# Transaction 359: Fraud Probability: 40.74%
# Transaction 360: Fraud Probability: 72.93%
# Transaction 361: Fraud Probability: 48.84%
# Transaction 362: Fraud Probability: 54.18%
# Transaction 363: Fraud Probability: 42.28%
# Transaction 364: Fraud Probability: 60.09%
# Transaction 365: Fraud Probability: 54.58%
# Transaction 366: Fraud Probability: 59.09%
# Transaction 367: Fraud Probability: 56.03%
# Transaction 368: Fraud Probability: 58.52%
# Transaction 369: Fraud Probability: 65.73%
# Transaction 370: Fraud Probability: 62.39%
# Transaction 371: Fraud Probability: 59.15%
# Transaction 372: Fraud Probability: 57.86%
# Transaction 373: Fraud Probability: 34.20%
# Transaction 374: Fraud Probability: 66.71%
# Transaction 375: Fraud Probability: 53.98%
# Transaction 376: Fraud Probability: 57.38%
# Transaction 377: Fraud Probability: 58.55%
# Transaction 378: Fraud Probability: 57.68%
# Transaction 379: Fraud Probability: 50.40%
# Transaction 380: Fraud Probability: 64.74%
# Transaction 381: Fraud Probability: 43.92%
# Transaction 382: Fraud Probability: 54.82%
# Transaction 383: Fraud Probability: 64.60%
# Transaction 384: Fraud Probability: 43.55%
# Transaction 385: Fraud Probability: 46.82%
# Transaction 386: Fraud Probability: 43.81%
# Transaction 387: Fraud Probability: 63.44%
# Transaction 388: Fraud Probability: 50.96%
# Transaction 389: Fraud Probability: 62.09%
# Transaction 390: Fraud Probability: 45.89%
# Transaction 391: Fraud Probability: 71.19%
# Transaction 392: Fraud Probability: 54.93%
# Transaction 393: Fraud Probability: 50.32%
# Transaction 394: Fraud Probability: 61.78%
# Transaction 395: Fraud Probability: 44.84%
# Transaction 396: Fraud Probability: 52.94%
# Transaction 397: Fraud Probability: 39.98%
# Transaction 398: Fraud Probability: 54.18%
# Transaction 399: Fraud Probability: 50.88%
# Transaction 400: Fraud Probability: 47.24%
# Transaction 401: Fraud Probability: 56.48%
# Transaction 402: Fraud Probability: 56.79%
# Transaction 403: Fraud Probability: 60.12%
# Transaction 404: Fraud Probability: 59.59%
# Transaction 405: Fraud Probability: 67.82%
# Transaction 406: Fraud Probability: 54.92%
# Transaction 407: Fraud Probability: 34.77%
# Transaction 408: Fraud Probability: 56.65%
# Transaction 409: Fraud Probability: 54.87%
# Transaction 410: Fraud Probability: 58.52%
# Transaction 411: Fraud Probability: 45.95%
# Transaction 412: Fraud Probability: 61.53%
# Transaction 413: Fraud Probability: 64.65%
# Transaction 414: Fraud Probability: 46.15%
# Transaction 415: Fraud Probability: 47.53%
# Transaction 416: Fraud Probability: 29.40%
# Transaction 417: Fraud Probability: 63.37%
# Transaction 418: Fraud Probability: 45.71%
# Transaction 419: Fraud Probability: 44.22%
# Transaction 420: Fraud Probability: 55.90%
# Transaction 421: Fraud Probability: 47.38%
# Transaction 422: Fraud Probability: 53.79%
# Transaction 423: Fraud Probability: 56.64%
# Transaction 424: Fraud Probability: 49.99%
# Transaction 425: Fraud Probability: 38.30%
# Transaction 426: Fraud Probability: 54.62%
# Transaction 427: Fraud Probability: 45.53%
# Transaction 428: Fraud Probability: 50.91%
# Transaction 429: Fraud Probability: 48.50%
# Transaction 430: Fraud Probability: 55.28%
# Transaction 431: Fraud Probability: 49.84%
# Transaction 432: Fraud Probability: 62.29%
# Transaction 433: Fraud Probability: 62.71%
# Transaction 434: Fraud Probability: 57.22%
# Transaction 435: Fraud Probability: 58.81%
# Transaction 436: Fraud Probability: 57.42%
# Transaction 437: Fraud Probability: 48.71%
# Transaction 438: Fraud Probability: 62.23%
# Transaction 439: Fraud Probability: 56.53%
# Transaction 440: Fraud Probability: 61.54%
# Transaction 441: Fraud Probability: 55.25%
# Transaction 442: Fraud Probability: 61.74%
# Transaction 443: Fraud Probability: 52.72%
# Transaction 444: Fraud Probability: 38.48%
# Transaction 445: Fraud Probability: 42.75%
# Transaction 446: Fraud Probability: 67.19%
# Transaction 447: Fraud Probability: 58.34%
# Transaction 448: Fraud Probability: 64.46%
# Transaction 449: Fraud Probability: 47.59%
# Transaction 450: Fraud Probability: 56.81%
# Transaction 451: Fraud Probability: 52.55%
# Transaction 452: Fraud Probability: 44.88%
# Transaction 453: Fraud Probability: 59.16%
# Transaction 454: Fraud Probability: 62.75%
# Transaction 455: Fraud Probability: 55.88%
# Transaction 456: Fraud Probability: 64.55%
# Transaction 457: Fraud Probability: 54.88%
# Transaction 458: Fraud Probability: 71.35%
# Transaction 459: Fraud Probability: 59.06%
# Transaction 460: Fraud Probability: 65.71%
# Transaction 461: Fraud Probability: 58.45%
# Transaction 462: Fraud Probability: 54.68%
# Transaction 463: Fraud Probability: 55.11%
# Transaction 464: Fraud Probability: 52.35%
# Transaction 465: Fraud Probability: 47.42%
# Transaction 466: Fraud Probability: 53.09%
# Transaction 467: Fraud Probability: 47.63%
# Transaction 468: Fraud Probability: 48.73%
# Transaction 469: Fraud Probability: 60.05%
# Transaction 470: Fraud Probability: 43.04%
# Transaction 471: Fraud Probability: 54.17%
# Transaction 472: Fraud Probability: 51.64%
# Transaction 473: Fraud Probability: 45.85%
# Transaction 474: Fraud Probability: 60.38%
# Transaction 475: Fraud Probability: 58.37%
# Transaction 476: Fraud Probability: 52.97%
# Transaction 477: Fraud Probability: 62.09%
# Transaction 478: Fraud Probability: 52.16%
# Transaction 479: Fraud Probability: 38.86%
# Transaction 480: Fraud Probability: 62.74%
# Transaction 481: Fraud Probability: 55.97%
# Transaction 482: Fraud Probability: 11.20%
# Transaction 483: Fraud Probability: 51.28%
# Transaction 484: Fraud Probability: 60.52%
# Transaction 485: Fraud Probability: 60.64%
# Transaction 486: Fraud Probability: 45.83%
# Transaction 487: Fraud Probability: 42.15%
# Transaction 488: Fraud Probability: 55.61%
# Transaction 489: Fraud Probability: 45.39%
# Transaction 490: Fraud Probability: 55.96%
# Transaction 491: Fraud Probability: 62.28%
# Transaction 492: Fraud Probability: 46.44%
# Transaction 493: Fraud Probability: 63.14%
# Transaction 494: Fraud Probability: 37.65%
# Transaction 495: Fraud Probability: 63.03%
# Transaction 496: Fraud Probability: 59.31%
# Transaction 497: Fraud Probability: 45.36%
# Transaction 498: Fraud Probability: 53.24%
# Transaction 499: Fraud Probability: 43.91%
# Transaction 500: Fraud Probability: 69.94%
# Transaction 501: Fraud Probability: 59.42%
# Transaction 502: Fraud Probability: 65.07%
# Transaction 503: Fraud Probability: 42.70%
# Transaction 504: Fraud Probability: 39.26%
# Transaction 505: Fraud Probability: 61.59%
# Transaction 506: Fraud Probability: 56.64%
# Transaction 507: Fraud Probability: 44.79%
# Transaction 508: Fraud Probability: 56.17%
# Transaction 509: Fraud Probability: 62.35%
# Transaction 510: Fraud Probability: 48.29%
# Transaction 511: Fraud Probability: 68.37%
# Transaction 512: Fraud Probability: 51.03%
# Transaction 513: Fraud Probability: 50.80%
# Transaction 514: Fraud Probability: 63.81%
# Transaction 515: Fraud Probability: 58.82%
# Transaction 516: Fraud Probability: 63.54%
# Transaction 517: Fraud Probability: 58.42%
# Transaction 518: Fraud Probability: 33.85%
# Transaction 519: Fraud Probability: 60.21%
# Transaction 520: Fraud Probability: 40.02%
# Transaction 521: Fraud Probability: 59.81%
# Transaction 522: Fraud Probability: 53.26%
# Transaction 523: Fraud Probability: 47.26%
# Transaction 524: Fraud Probability: 57.48%
# Transaction 525: Fraud Probability: 59.26%
# Transaction 526: Fraud Probability: 66.66%
# Transaction 527: Fraud Probability: 58.77%
# Transaction 528: Fraud Probability: 57.59%
# Transaction 529: Fraud Probability: 37.63%
# Transaction 530: Fraud Probability: 57.39%
# Transaction 531: Fraud Probability: 49.35%
# Transaction 532: Fraud Probability: 49.68%
# Transaction 533: Fraud Probability: 59.04%
# Transaction 534: Fraud Probability: 55.94%
# Transaction 535: Fraud Probability: 57.47%
# Transaction 536: Fraud Probability: 54.60%
# Transaction 537: Fraud Probability: 64.92%
# Transaction 538: Fraud Probability: 65.12%
# Transaction 539: Fraud Probability: 55.62%
# Transaction 540: Fraud Probability: 54.77%
# Transaction 541: Fraud Probability: 58.00%
# Transaction 542: Fraud Probability: 50.05%
# Transaction 543: Fraud Probability: 54.62%
# Transaction 544: Fraud Probability: 61.20%
# Transaction 545: Fraud Probability: 62.86%
# Transaction 546: Fraud Probability: 63.54%
# Transaction 547: Fraud Probability: 63.57%
# Transaction 548: Fraud Probability: 46.14%
# Transaction 549: Fraud Probability: 54.12%
# Transaction 550: Fraud Probability: 61.70%
# Transaction 551: Fraud Probability: 51.90%
# Transaction 552: Fraud Probability: 49.76%
# Transaction 553: Fraud Probability: 48.38%
# Transaction 554: Fraud Probability: 52.34%
# Transaction 555: Fraud Probability: 64.52%
# Transaction 556: Fraud Probability: 51.92%
# Transaction 557: Fraud Probability: 60.17%
# Transaction 558: Fraud Probability: 57.20%
# Transaction 559: Fraud Probability: 58.63%
# Transaction 560: Fraud Probability: 60.38%
# Transaction 561: Fraud Probability: 59.97%
# Transaction 562: Fraud Probability: 56.40%
# Transaction 563: Fraud Probability: 65.35%
# Transaction 564: Fraud Probability: 42.15%
# Transaction 565: Fraud Probability: 48.34%
# Transaction 566: Fraud Probability: 52.24%
# Transaction 567: Fraud Probability: 49.99%
# Transaction 568: Fraud Probability: 57.82%
# Transaction 569: Fraud Probability: 54.38%
# Transaction 570: Fraud Probability: 54.53%
# Transaction 571: Fraud Probability: 62.00%
# Transaction 572: Fraud Probability: 60.27%
# Transaction 573: Fraud Probability: 63.17%
# Transaction 574: Fraud Probability: 60.05%
# Transaction 575: Fraud Probability: 37.14%
# Transaction 576: Fraud Probability: 60.52%
# Transaction 577: Fraud Probability: 49.70%
# Transaction 578: Fraud Probability: 58.82%
# Transaction 579: Fraud Probability: 67.44%
# Transaction 580: Fraud Probability: 48.81%
# Transaction 581: Fraud Probability: 56.84%
# Transaction 582: Fraud Probability: 55.24%
# Transaction 583: Fraud Probability: 59.99%
# Transaction 584: Fraud Probability: 63.36%
# Transaction 585: Fraud Probability: 36.60%
# Transaction 586: Fraud Probability: 63.31%
# Transaction 587: Fraud Probability: 55.54%
# Transaction 588: Fraud Probability: 47.42%
# Transaction 589: Fraud Probability: 60.11%
# Transaction 590: Fraud Probability: 19.78%
# Transaction 591: Fraud Probability: 63.25%
# Transaction 592: Fraud Probability: 48.88%
# Transaction 593: Fraud Probability: 31.62%
# Transaction 594: Fraud Probability: 56.17%
# Transaction 595: Fraud Probability: 68.86%
# Transaction 596: Fraud Probability: 59.33%
# Transaction 597: Fraud Probability: 52.84%
# Transaction 598: Fraud Probability: 51.14%
# Transaction 599: Fraud Probability: 44.52%
# Transaction 600: Fraud Probability: 57.86%
# Transaction 601: Fraud Probability: 63.37%
# Transaction 602: Fraud Probability: 54.89%
# Transaction 603: Fraud Probability: 54.03%
# Transaction 604: Fraud Probability: 60.11%
# Transaction 605: Fraud Probability: 53.69%
# Transaction 606: Fraud Probability: 51.15%
# Transaction 607: Fraud Probability: 64.89%
# Transaction 608: Fraud Probability: 57.43%
# Transaction 609: Fraud Probability: 46.49%
# Transaction 610: Fraud Probability: 48.58%
# Transaction 611: Fraud Probability: 34.19%
# Transaction 612: Fraud Probability: 51.75%
# Transaction 613: Fraud Probability: 60.10%
# Transaction 614: Fraud Probability: 49.83%
# Transaction 615: Fraud Probability: 55.57%
# Transaction 616: Fraud Probability: 62.17%
# Transaction 617: Fraud Probability: 54.95%
# Transaction 618: Fraud Probability: 69.42%
# Transaction 619: Fraud Probability: 60.62%
# Transaction 620: Fraud Probability: 55.67%
# Transaction 621: Fraud Probability: 62.49%
# Transaction 622: Fraud Probability: 58.07%
# Transaction 623: Fraud Probability: 43.62%
# Transaction 624: Fraud Probability: 61.07%
# Transaction 625: Fraud Probability: 46.41%
# Transaction 626: Fraud Probability: 70.26%
# Transaction 627: Fraud Probability: 57.76%
# Transaction 628: Fraud Probability: 50.31%
# Transaction 629: Fraud Probability: 45.98%
# Transaction 630: Fraud Probability: 46.27%
# Transaction 631: Fraud Probability: 38.63%
# Transaction 632: Fraud Probability: 55.91%
# Transaction 633: Fraud Probability: 55.99%
# Transaction 634: Fraud Probability: 44.09%
# Transaction 635: Fraud Probability: 51.51%
# Transaction 636: Fraud Probability: 74.15%
# Transaction 637: Fraud Probability: 60.18%
# Transaction 638: Fraud Probability: 45.97%
# Transaction 639: Fraud Probability: 63.84%
# Transaction 640: Fraud Probability: 64.93%
# Transaction 641: Fraud Probability: 59.89%
# Transaction 642: Fraud Probability: 43.81%
# Transaction 643: Fraud Probability: 63.97%
# Transaction 644: Fraud Probability: 55.11%
# Transaction 645: Fraud Probability: 65.13%
# Transaction 646: Fraud Probability: 54.05%
# Transaction 647: Fraud Probability: 51.45%
# Transaction 648: Fraud Probability: 60.53%
# Transaction 649: Fraud Probability: 51.02%
# Transaction 650: Fraud Probability: 56.24%
# Transaction 651: Fraud Probability: 70.43%
# Transaction 652: Fraud Probability: 71.35%
# Transaction 653: Fraud Probability: 57.84%
# Transaction 654: Fraud Probability: 56.64%
# Transaction 655: Fraud Probability: 53.19%
# Transaction 656: Fraud Probability: 58.85%
# Transaction 657: Fraud Probability: 56.56%
# Transaction 658: Fraud Probability: 58.39%
# Transaction 659: Fraud Probability: 43.09%
# Transaction 660: Fraud Probability: 38.37%
# Transaction 661: Fraud Probability: 52.29%
# Transaction 662: Fraud Probability: 53.78%
# Transaction 663: Fraud Probability: 53.75%
# Transaction 664: Fraud Probability: 63.15%
# Transaction 665: Fraud Probability: 56.15%
# Transaction 666: Fraud Probability: 68.89%
# Transaction 667: Fraud Probability: 63.32%
# Transaction 668: Fraud Probability: 62.01%
# Transaction 669: Fraud Probability: 61.53%
# Transaction 670: Fraud Probability: 57.79%
# Transaction 671: Fraud Probability: 36.04%
# Transaction 672: Fraud Probability: 74.69%
# Transaction 673: Fraud Probability: 51.27%
# Transaction 674: Fraud Probability: 48.59%
# Transaction 675: Fraud Probability: 54.49%
# Transaction 676: Fraud Probability: 48.82%
# Transaction 677: Fraud Probability: 56.99%
# Transaction 678: Fraud Probability: 57.81%
# Transaction 679: Fraud Probability: 64.57%
# Transaction 680: Fraud Probability: 65.97%
# Transaction 681: Fraud Probability: 44.72%
# Transaction 682: Fraud Probability: 63.72%
# Transaction 683: Fraud Probability: 49.59%
# Transaction 684: Fraud Probability: 57.82%
# Transaction 685: Fraud Probability: 59.40%
# Transaction 686: Fraud Probability: 51.57%
# Transaction 687: Fraud Probability: 56.12%
# Transaction 688: Fraud Probability: 57.10%
# Transaction 689: Fraud Probability: 62.82%
# Transaction 690: Fraud Probability: 49.34%
# Transaction 691: Fraud Probability: 42.98%
# Transaction 692: Fraud Probability: 48.22%
# Transaction 693: Fraud Probability: 57.92%
# Transaction 694: Fraud Probability: 58.99%
# Transaction 695: Fraud Probability: 52.96%
# Transaction 696: Fraud Probability: 58.85%
# Transaction 697: Fraud Probability: 63.51%
# Transaction 698: Fraud Probability: 59.76%
# Transaction 699: Fraud Probability: 6.10%
# Transaction 700: Fraud Probability: 47.04%
# Transaction 701: Fraud Probability: 61.76%
# Transaction 702: Fraud Probability: 52.63%
# Transaction 703: Fraud Probability: 38.98%
# Transaction 704: Fraud Probability: 59.37%
# Transaction 705: Fraud Probability: 49.35%
# Transaction 706: Fraud Probability: 45.42%
# Transaction 707: Fraud Probability: 67.15%
# Transaction 708: Fraud Probability: 58.75%
# Transaction 709: Fraud Probability: 58.05%
# Transaction 710: Fraud Probability: 40.48%
# Transaction 711: Fraud Probability: 58.83%
# Transaction 712: Fraud Probability: 46.46%
# Transaction 713: Fraud Probability: 51.03%
# Transaction 714: Fraud Probability: 42.52%
# Transaction 715: Fraud Probability: 43.63%
# Transaction 716: Fraud Probability: 56.94%
# Transaction 717: Fraud Probability: 57.19%
# Transaction 718: Fraud Probability: 62.00%
# Transaction 719: Fraud Probability: 50.45%
# Transaction 720: Fraud Probability: 52.45%
# Transaction 721: Fraud Probability: 60.17%
# Transaction 722: Fraud Probability: 59.15%
# Transaction 723: Fraud Probability: 56.95%
# Transaction 724: Fraud Probability: 59.08%
# Transaction 725: Fraud Probability: 45.79%
# Transaction 726: Fraud Probability: 56.88%
# Transaction 727: Fraud Probability: 50.35%
# Transaction 728: Fraud Probability: 63.45%
# Transaction 729: Fraud Probability: 59.04%
# Transaction 730: Fraud Probability: 59.53%
# Transaction 731: Fraud Probability: 63.29%
# Transaction 732: Fraud Probability: 61.43%
# Transaction 733: Fraud Probability: 22.71%
# Transaction 734: Fraud Probability: 56.94%
# Transaction 735: Fraud Probability: 43.61%
# Transaction 736: Fraud Probability: 58.90%
# Transaction 737: Fraud Probability: 64.14%
# Transaction 738: Fraud Probability: 57.40%
# Transaction 739: Fraud Probability: 51.01%
# Transaction 740: Fraud Probability: 58.60%
# Transaction 741: Fraud Probability: 65.07%
# Transaction 742: Fraud Probability: 39.98%
# Transaction 743: Fraud Probability: 56.40%
# Transaction 744: Fraud Probability: 58.07%
# Transaction 745: Fraud Probability: 57.18%
# Transaction 746: Fraud Probability: 58.62%
# Transaction 747: Fraud Probability: 51.95%
# Transaction 748: Fraud Probability: 55.21%
# Transaction 749: Fraud Probability: 53.07%
# Transaction 750: Fraud Probability: 56.99%
# Transaction 751: Fraud Probability: 58.12%
# Transaction 752: Fraud Probability: 56.84%
# Transaction 753: Fraud Probability: 53.84%
# Transaction 754: Fraud Probability: 57.57%
# Transaction 755: Fraud Probability: 61.13%
# Transaction 756: Fraud Probability: 43.66%
# Transaction 757: Fraud Probability: 38.09%
# Transaction 758: Fraud Probability: 60.90%
# Transaction 759: Fraud Probability: 57.73%
# Transaction 760: Fraud Probability: 67.18%
# Transaction 761: Fraud Probability: 51.02%
# Transaction 762: Fraud Probability: 46.97%
# Transaction 763: Fraud Probability: 50.03%
# Transaction 764: Fraud Probability: 59.44%
# Transaction 765: Fraud Probability: 48.14%
# Transaction 766: Fraud Probability: 52.44%
# Transaction 767: Fraud Probability: 43.77%
# Transaction 768: Fraud Probability: 46.82%
# Transaction 769: Fraud Probability: 56.38%
# Transaction 770: Fraud Probability: 50.82%
# Transaction 771: Fraud Probability: 48.26%
# Transaction 772: Fraud Probability: 60.30%
# Transaction 773: Fraud Probability: 59.83%
# Transaction 774: Fraud Probability: 59.53%
# Transaction 775: Fraud Probability: 50.36%
# Transaction 776: Fraud Probability: 55.38%
# Transaction 777: Fraud Probability: 51.41%
# Transaction 778: Fraud Probability: 53.61%
# Transaction 779: Fraud Probability: 60.17%
# Transaction 780: Fraud Probability: 50.60%
# Transaction 781: Fraud Probability: 46.94%
# Transaction 782: Fraud Probability: 47.26%
# Transaction 783: Fraud Probability: 52.22%
# Transaction 784: Fraud Probability: 55.67%
# Transaction 785: Fraud Probability: 38.93%
# Transaction 786: Fraud Probability: 52.29%
# Transaction 787: Fraud Probability: 41.21%
# Transaction 788: Fraud Probability: 10.77%
# Transaction 789: Fraud Probability: 56.62%
# Transaction 790: Fraud Probability: 63.16%
# Transaction 791: Fraud Probability: 62.27%
# Transaction 792: Fraud Probability: 65.37%
# Transaction 793: Fraud Probability: 61.86%
# Transaction 794: Fraud Probability: 41.54%
# Transaction 795: Fraud Probability: 61.34%
# Transaction 796: Fraud Probability: 57.79%
# Transaction 797: Fraud Probability: 49.87%
# Transaction 798: Fraud Probability: 49.61%
# Transaction 799: Fraud Probability: 50.22%
# Transaction 800: Fraud Probability: 56.83%
# Transaction 801: Fraud Probability: 49.25%
# Transaction 802: Fraud Probability: 58.80%
# Transaction 803: Fraud Probability: 42.42%
# Transaction 804: Fraud Probability: 52.68%
# Transaction 805: Fraud Probability: 54.03%
# Transaction 806: Fraud Probability: 59.55%
# Transaction 807: Fraud Probability: 57.71%
# Transaction 808: Fraud Probability: 52.99%
# Transaction 809: Fraud Probability: 51.75%
# Transaction 810: Fraud Probability: 67.66%
# Transaction 811: Fraud Probability: 64.21%
# Transaction 812: Fraud Probability: 59.96%
# Transaction 813: Fraud Probability: 45.72%
# Transaction 814: Fraud Probability: 60.65%
# Transaction 815: Fraud Probability: 68.37%
# Transaction 816: Fraud Probability: 41.50%
# Transaction 817: Fraud Probability: 68.29%
# Transaction 818: Fraud Probability: 39.51%
# Transaction 819: Fraud Probability: 58.08%
# Transaction 820: Fraud Probability: 51.41%
# Transaction 821: Fraud Probability: 46.61%
# Transaction 822: Fraud Probability: 46.88%
# Transaction 823: Fraud Probability: 61.79%
# Transaction 824: Fraud Probability: 53.29%
# Transaction 825: Fraud Probability: 49.83%
# Transaction 826: Fraud Probability: 56.24%
# Transaction 827: Fraud Probability: 52.40%
# Transaction 828: Fraud Probability: 61.42%
# Transaction 829: Fraud Probability: 43.85%
# Transaction 830: Fraud Probability: 32.12%
# Transaction 831: Fraud Probability: 50.53%
# Transaction 832: Fraud Probability: 48.07%
# Transaction 833: Fraud Probability: 55.04%
# Transaction 834: Fraud Probability: 65.77%
# Transaction 835: Fraud Probability: 53.22%
# Transaction 836: Fraud Probability: 55.33%
# Transaction 837: Fraud Probability: 38.58%
# Transaction 838: Fraud Probability: 39.57%
# Transaction 839: Fraud Probability: 61.32%
# Transaction 840: Fraud Probability: 63.37%
# Transaction 841: Fraud Probability: 59.85%
# Transaction 842: Fraud Probability: 60.00%
# Transaction 843: Fraud Probability: 62.53%
# Transaction 844: Fraud Probability: 46.71%
# Transaction 845: Fraud Probability: 55.59%
# Transaction 846: Fraud Probability: 60.24%
# Transaction 847: Fraud Probability: 60.98%
# Transaction 848: Fraud Probability: 61.64%
# Transaction 849: Fraud Probability: 63.91%
# Transaction 850: Fraud Probability: 45.39%
# Transaction 851: Fraud Probability: 38.24%
# Transaction 852: Fraud Probability: 57.17%
# Transaction 853: Fraud Probability: 55.66%
# Transaction 854: Fraud Probability: 60.12%
# Transaction 855: Fraud Probability: 46.01%
# Transaction 856: Fraud Probability: 48.19%
# Transaction 857: Fraud Probability: 54.60%
# Transaction 858: Fraud Probability: 62.60%
# Transaction 859: Fraud Probability: 50.34%
# Transaction 860: Fraud Probability: 64.60%
# Transaction 861: Fraud Probability: 68.16%
# Transaction 862: Fraud Probability: 50.76%
# Transaction 863: Fraud Probability: 28.22%
# Transaction 864: Fraud Probability: 43.36%
# Transaction 865: Fraud Probability: 50.80%
# Transaction 866: Fraud Probability: 68.20%
# Transaction 867: Fraud Probability: 53.01%
# Transaction 868: Fraud Probability: 61.53%
# Transaction 869: Fraud Probability: 70.69%
# Transaction 870: Fraud Probability: 74.61%
# Transaction 871: Fraud Probability: 55.09%
# Transaction 872: Fraud Probability: 58.16%
# Transaction 873: Fraud Probability: 39.13%
# Transaction 874: Fraud Probability: 61.04%
# Transaction 875: Fraud Probability: 69.67%
# Transaction 876: Fraud Probability: 56.87%
# Transaction 877: Fraud Probability: 56.98%
# Transaction 878: Fraud Probability: 38.52%
# Transaction 879: Fraud Probability: 55.13%
# Transaction 880: Fraud Probability: 56.43%
# Transaction 881: Fraud Probability: 51.01%
# Transaction 882: Fraud Probability: 53.33%
# Transaction 883: Fraud Probability: 54.14%
# Transaction 884: Fraud Probability: 59.75%
# Transaction 885: Fraud Probability: 49.42%
# Transaction 886: Fraud Probability: 49.89%
# Transaction 887: Fraud Probability: 50.16%
# Transaction 888: Fraud Probability: 59.65%
# Transaction 889: Fraud Probability: 33.14%
# Transaction 890: Fraud Probability: 58.66%
# Transaction 891: Fraud Probability: 66.84%
# Transaction 892: Fraud Probability: 41.89%
# Transaction 893: Fraud Probability: 61.65%
# Transaction 894: Fraud Probability: 59.75%
# Transaction 895: Fraud Probability: 63.47%
# Transaction 896: Fraud Probability: 48.06%
# Transaction 897: Fraud Probability: 54.12%
# Transaction 898: Fraud Probability: 62.93%
# Transaction 899: Fraud Probability: 55.53%
# Transaction 900: Fraud Probability: 63.87%
# Transaction 901: Fraud Probability: 51.19%
# Transaction 902: Fraud Probability: 62.67%
# Transaction 903: Fraud Probability: 37.69%
# Transaction 904: Fraud Probability: 48.98%
# Transaction 905: Fraud Probability: 47.25%
# Transaction 906: Fraud Probability: 52.98%
# Transaction 907: Fraud Probability: 47.65%
# Transaction 908: Fraud Probability: 45.95%
# Transaction 909: Fraud Probability: 32.92%
# Transaction 910: Fraud Probability: 67.40%
# Transaction 911: Fraud Probability: 50.32%
# Transaction 912: Fraud Probability: 61.24%
# Transaction 913: Fraud Probability: 50.49%
# Transaction 914: Fraud Probability: 24.34%
# Transaction 915: Fraud Probability: 49.65%
# Transaction 916: Fraud Probability: 50.72%
# Transaction 917: Fraud Probability: 68.06%
# Transaction 918: Fraud Probability: 47.66%
# Transaction 919: Fraud Probability: 64.59%
# Transaction 920: Fraud Probability: 42.47%
# Transaction 921: Fraud Probability: 57.63%
# Transaction 922: Fraud Probability: 54.26%
# Transaction 923: Fraud Probability: 44.25%
# Transaction 924: Fraud Probability: 53.60%
# Transaction 925: Fraud Probability: 52.82%
# Transaction 926: Fraud Probability: 58.34%
# Transaction 927: Fraud Probability: 62.94%
# Transaction 928: Fraud Probability: 37.00%
# Transaction 929: Fraud Probability: 56.75%
# Transaction 930: Fraud Probability: 56.17%
# Transaction 931: Fraud Probability: 55.78%
# Transaction 932: Fraud Probability: 36.74%
# Transaction 933: Fraud Probability: 59.63%
# Transaction 934: Fraud Probability: 61.01%
# Transaction 935: Fraud Probability: 60.84%
# Transaction 936: Fraud Probability: 55.85%
# Transaction 937: Fraud Probability: 65.45%
# Transaction 938: Fraud Probability: 62.13%
# Transaction 939: Fraud Probability: 51.09%
# Transaction 940: Fraud Probability: 50.23%
# Transaction 941: Fraud Probability: 59.69%
# Transaction 942: Fraud Probability: 62.08%
# Transaction 943: Fraud Probability: 53.32%
# Transaction 944: Fraud Probability: 55.50%
# Transaction 945: Fraud Probability: 42.49%
# Transaction 946: Fraud Probability: 62.17%
# Transaction 947: Fraud Probability: 59.84%
# Transaction 948: Fraud Probability: 51.83%
# Transaction 949: Fraud Probability: 61.59%
# Transaction 950: Fraud Probability: 39.96%
# Transaction 951: Fraud Probability: 50.87%
# Transaction 952: Fraud Probability: 55.01%
# Transaction 953: Fraud Probability: 69.42%
# Transaction 954: Fraud Probability: 61.64%
# Transaction 955: Fraud Probability: 43.84%
# Transaction 956: Fraud Probability: 57.88%
# Transaction 957: Fraud Probability: 53.09%
# Transaction 958: Fraud Probability: 64.64%
# Transaction 959: Fraud Probability: 53.61%
# Transaction 960: Fraud Probability: 45.54%
# Transaction 961: Fraud Probability: 55.09%
# Transaction 962: Fraud Probability: 62.67%
# Transaction 963: Fraud Probability: 40.81%
# Transaction 964: Fraud Probability: 65.44%
# Transaction 965: Fraud Probability: 54.77%
# Transaction 966: Fraud Probability: 55.27%
# Transaction 967: Fraud Probability: 47.19%
# Transaction 968: Fraud Probability: 56.89%
# Transaction 969: Fraud Probability: 46.77%
# Transaction 970: Fraud Probability: 57.53%
# Transaction 971: Fraud Probability: 52.72%
# Transaction 972: Fraud Probability: 58.56%
# Transaction 973: Fraud Probability: 43.35%
# Transaction 974: Fraud Probability: 60.02%
# Transaction 975: Fraud Probability: 52.30%
# Transaction 976: Fraud Probability: 50.38%
# Transaction 977: Fraud Probability: 51.46%
# Transaction 978: Fraud Probability: 67.98%
# Transaction 979: Fraud Probability: 58.26%
# Transaction 980: Fraud Probability: 59.58%
# Transaction 981: Fraud Probability: 59.72%
# Transaction 982: Fraud Probability: 65.05%
# Transaction 983: Fraud Probability: 57.79%
# Transaction 984: Fraud Probability: 39.88%
# Transaction 985: Fraud Probability: 40.36%
# Transaction 986: Fraud Probability: 61.24%
# Transaction 987: Fraud Probability: 59.10%
# Transaction 988: Fraud Probability: 60.78%
# Transaction 989: Fraud Probability: 15.32%
# Transaction 990: Fraud Probability: 51.75%
# Transaction 991: Fraud Probability: 45.77%
# Transaction 992: Fraud Probability: 57.29%
# Transaction 993: Fraud Probability: 56.66%
# Transaction 994: Fraud Probability: 50.28%
# Transaction 995: Fraud Probability: 20.68%
# Transaction 996: Fraud Probability: 44.34%
# Transaction 997: Fraud Probability: 58.29%
# Transaction 998: Fraud Probability: 49.13%
# Transaction 999: Fraud Probability: 50.57%
# Transaction 1000: Fraud Probability: 52.78%
# Transaction 1001: Fraud Probability: 56.92%
# Transaction 1002: Fraud Probability: 56.83%
# Transaction 1003: Fraud Probability: 56.67%
# Transaction 1004: Fraud Probability: 49.07%
# Transaction 1005: Fraud Probability: 45.61%
# Transaction 1006: Fraud Probability: 57.92%
# Transaction 1007: Fraud Probability: 62.27%
# Transaction 1008: Fraud Probability: 59.34%
# Transaction 1009: Fraud Probability: 53.85%
# Transaction 1010: Fraud Probability: 56.83%
# Transaction 1011: Fraud Probability: 60.13%
# Transaction 1012: Fraud Probability: 58.99%
# Transaction 1013: Fraud Probability: 54.72%
# Transaction 1014: Fraud Probability: 72.33%
# Transaction 1015: Fraud Probability: 49.82%
# Transaction 1016: Fraud Probability: 65.08%
# Transaction 1017: Fraud Probability: 59.53%
# Transaction 1018: Fraud Probability: 68.47%
# Transaction 1019: Fraud Probability: 67.73%
# Transaction 1020: Fraud Probability: 55.03%
# Transaction 1021: Fraud Probability: 53.33%
# Transaction 1022: Fraud Probability: 57.06%
# Transaction 1023: Fraud Probability: 54.78%
# Transaction 1024: Fraud Probability: 68.64%
# Transaction 1025: Fraud Probability: 42.87%
# Transaction 1026: Fraud Probability: 63.62%
# Transaction 1027: Fraud Probability: 62.71%
# Transaction 1028: Fraud Probability: 42.20%
# Transaction 1029: Fraud Probability: 38.42%
# Transaction 1030: Fraud Probability: 56.20%
# Transaction 1031: Fraud Probability: 35.84%
# Transaction 1032: Fraud Probability: 60.36%
# Transaction 1033: Fraud Probability: 51.55%
# Transaction 1034: Fraud Probability: 62.70%
# Transaction 1035: Fraud Probability: 55.36%
# Transaction 1036: Fraud Probability: 45.71%
# Transaction 1037: Fraud Probability: 56.34%
# Transaction 1038: Fraud Probability: 68.57%
# Transaction 1039: Fraud Probability: 46.47%
# Transaction 1040: Fraud Probability: 40.49%
# Transaction 1041: Fraud Probability: 53.86%
# Transaction 1042: Fraud Probability: 59.73%
# Transaction 1043: Fraud Probability: 57.41%
# Transaction 1044: Fraud Probability: 38.41%
# Transaction 1045: Fraud Probability: 64.45%
# Transaction 1046: Fraud Probability: 42.28%
# Transaction 1047: Fraud Probability: 50.07%
# Transaction 1048: Fraud Probability: 57.79%
# Transaction 1049: Fraud Probability: 55.04%
# Transaction 1050: Fraud Probability: 56.36%
# Transaction 1051: Fraud Probability: 48.76%
# Transaction 1052: Fraud Probability: 51.84%
# Transaction 1053: Fraud Probability: 56.02%
# Transaction 1054: Fraud Probability: 59.19%
# Transaction 1055: Fraud Probability: 48.73%
# Transaction 1056: Fraud Probability: 61.42%
# Transaction 1057: Fraud Probability: 36.80%
# Transaction 1058: Fraud Probability: 61.74%
# Transaction 1059: Fraud Probability: 62.89%
# Transaction 1060: Fraud Probability: 35.46%
# Transaction 1061: Fraud Probability: 52.37%
# Transaction 1062: Fraud Probability: 60.28%
# Transaction 1063: Fraud Probability: 53.02%
# Transaction 1064: Fraud Probability: 39.92%
# Transaction 1065: Fraud Probability: 55.10%
# Transaction 1066: Fraud Probability: 50.89%
# Transaction 1067: Fraud Probability: 51.98%
# Transaction 1068: Fraud Probability: 54.52%
# Transaction 1069: Fraud Probability: 54.96%
# Transaction 1070: Fraud Probability: 42.54%
# Transaction 1071: Fraud Probability: 61.66%
# Transaction 1072: Fraud Probability: 49.80%
# Transaction 1073: Fraud Probability: 54.55%
# Transaction 1074: Fraud Probability: 57.23%
# Transaction 1075: Fraud Probability: 53.81%
# Transaction 1076: Fraud Probability: 64.43%
# Transaction 1077: Fraud Probability: 58.31%
# Transaction 1078: Fraud Probability: 61.39%
# Transaction 1079: Fraud Probability: 55.86%
# Transaction 1080: Fraud Probability: 40.77%
# Transaction 1081: Fraud Probability: 56.41%
# Transaction 1082: Fraud Probability: 58.12%
# Transaction 1083: Fraud Probability: 46.26%
# Transaction 1084: Fraud Probability: 62.61%
# Transaction 1085: Fraud Probability: 57.45%
# Transaction 1086: Fraud Probability: 60.55%
# Transaction 1087: Fraud Probability: 55.07%
# Transaction 1088: Fraud Probability: 57.74%
# Transaction 1089: Fraud Probability: 47.47%
# Transaction 1090: Fraud Probability: 52.31%
# Transaction 1091: Fraud Probability: 65.06%
# Transaction 1092: Fraud Probability: 55.34%
# Transaction 1093: Fraud Probability: 50.97%
# Transaction 1094: Fraud Probability: 51.98%
# Transaction 1095: Fraud Probability: 59.64%
# Transaction 1096: Fraud Probability: 48.02%
# Transaction 1097: Fraud Probability: 65.19%
# Transaction 1098: Fraud Probability: 58.33%
# Transaction 1099: Fraud Probability: 62.64%
# Transaction 1100: Fraud Probability: 53.11%
# Transaction 1101: Fraud Probability: 61.82%
# Transaction 1102: Fraud Probability: 51.55%
# Transaction 1103: Fraud Probability: 55.03%
# Transaction 1104: Fraud Probability: 52.07%
# Transaction 1105: Fraud Probability: 54.76%
# Transaction 1106: Fraud Probability: 46.48%
# Transaction 1107: Fraud Probability: 47.37%
# Transaction 1108: Fraud Probability: 73.30%
# Transaction 1109: Fraud Probability: 61.57%
# Transaction 1110: Fraud Probability: 17.56%
# Transaction 1111: Fraud Probability: 46.17%
# Transaction 1112: Fraud Probability: 48.10%
# Transaction 1113: Fraud Probability: 61.25%
# Transaction 1114: Fraud Probability: 47.88%
# Transaction 1115: Fraud Probability: 51.28%
# ...
# Transaction 4387: Fraud Probability: 51.22%
# Transaction 4388: Fraud Probability: 52.23%
# Transaction 4389: Fraud Probability: 44.64%
# Transaction 4390: Fraud Probability: 58.40%
# Transaction 4391: Fraud Probability: 64.65%
# Transaction 4392: Fraud Probability: 67.30%
# Transaction 4393: Fraud Probability: 59.20%
# Transaction 4394: Fraud Probability: 46.14%
# Transaction 4395: Fraud Probability: 47.94%
# Transaction 4396: Fraud Probability: 55.64%
# Transaction 4397: Fraud Probability: 68.86%
# Transaction 4398: Fraud Probability: 49.55%
# Transaction 4399: Fraud Probability: 59.21%
# Transaction 4400: Fraud Probability: 55.97%
# Transaction 4401: Fraud Probability: 39.24%
# Transaction 4402: Fraud Probability: 64.29%
# Transaction 4403: Fraud Probability: 54.77%
# Transaction 4404: Fraud Probability: 39.40%
# Transaction 4405: Fraud Probability: 65.53%
# Transaction 4406: Fraud Probability: 50.36%
# Transaction 4407: Fraud Probability: 56.36%
# Transaction 4408: Fraud Probability: 62.29%
# Transaction 4409: Fraud Probability: 16.40%
# Transaction 4410: Fraud Probability: 46.61%
# Transaction 4411: Fraud Probability: 59.76%
# Transaction 4412: Fraud Probability: 41.70%
# Transaction 4413: Fraud Probability: 49.36%
# Transaction 4414: Fraud Probability: 62.66%
# Transaction 4415: Fraud Probability: 44.65%
# Transaction 4416: Fraud Probability: 62.77%
# Transaction 4417: Fraud Probability: 64.51%
# Transaction 4418: Fraud Probability: 59.57%
# Transaction 4419: Fraud Probability: 56.27%
# Transaction 4420: Fraud Probability: 64.46%
# Transaction 4421: Fraud Probability: 66.48%
# Transaction 4422: Fraud Probability: 63.89%
# Transaction 4423: Fraud Probability: 56.66%
# Transaction 4424: Fraud Probability: 43.83%
# Transaction 4425: Fraud Probability: 66.55%
# Transaction 4426: Fraud Probability: 55.08%
# Transaction 4427: Fraud Probability: 48.96%
# Transaction 4428: Fraud Probability: 58.99%
# Transaction 4429: Fraud Probability: 52.33%
# Transaction 4430: Fraud Probability: 49.38%
# Transaction 4431: Fraud Probability: 49.13%
# Transaction 4432: Fraud Probability: 63.94%
# Transaction 4433: Fraud Probability: 35.11%
# Transaction 4434: Fraud Probability: 55.90%
# Transaction 4435: Fraud Probability: 60.33%
# Transaction 4436: Fraud Probability: 56.09%
# Transaction 4437: Fraud Probability: 44.44%
# Transaction 4438: Fraud Probability: 53.45%
# Transaction 4439: Fraud Probability: 52.90%
# Transaction 4440: Fraud Probability: 56.23%
# Transaction 4441: Fraud Probability: 34.57%
# Transaction 4442: Fraud Probability: 48.75%
# Transaction 4443: Fraud Probability: 66.16%
# Transaction 4444: Fraud Probability: 52.98%
# Transaction 4445: Fraud Probability: 53.05%
# Transaction 4446: Fraud Probability: 53.35%
# Transaction 4447: Fraud Probability: 56.29%
# Transaction 4448: Fraud Probability: 62.77%
# Transaction 4449: Fraud Probability: 42.31%
# Transaction 4450: Fraud Probability: 55.43%
# Transaction 4451: Fraud Probability: 40.28%
# Transaction 4452: Fraud Probability: 41.96%
# Transaction 4453: Fraud Probability: 38.71%
# Transaction 4454: Fraud Probability: 46.06%
# Transaction 4455: Fraud Probability: 63.33%
# Transaction 4456: Fraud Probability: 58.35%
# Transaction 4457: Fraud Probability: 58.48%
# Transaction 4458: Fraud Probability: 36.86%
# Transaction 4459: Fraud Probability: 64.73%
# Transaction 4460: Fraud Probability: 46.79%
# Transaction 4461: Fraud Probability: 39.56%
# Transaction 4462: Fraud Probability: 64.25%
# Transaction 4463: Fraud Probability: 63.10%
# Transaction 4464: Fraud Probability: 38.86%
# Transaction 4465: Fraud Probability: 56.58%
# Transaction 4466: Fraud Probability: 66.51%
# Transaction 4467: Fraud Probability: 62.55%
# Transaction 4468: Fraud Probability: 49.46%
# Transaction 4469: Fraud Probability: 64.36%
# Transaction 4470: Fraud Probability: 49.53%
# Transaction 4471: Fraud Probability: 64.04%
# Transaction 4472: Fraud Probability: 62.36%
# Transaction 4473: Fraud Probability: 74.32%
# Transaction 4474: Fraud Probability: 51.72%
# Transaction 4475: Fraud Probability: 59.13%
# Transaction 4476: Fraud Probability: 54.27%
# Transaction 4477: Fraud Probability: 59.87%
# Transaction 4478: Fraud Probability: 47.31%
# Transaction 4479: Fraud Probability: 60.71%
# Transaction 4480: Fraud Probability: 65.59%
# Transaction 4481: Fraud Probability: 59.46%
# Transaction 4482: Fraud Probability: 57.61%
# Transaction 4483: Fraud Probability: 54.83%
# Transaction 4484: Fraud Probability: 53.98%
# Transaction 4485: Fraud Probability: 45.70%
# Transaction 4486: Fraud Probability: 69.56%
# Transaction 4487: Fraud Probability: 57.88%
# Transaction 4488: Fraud Probability: 52.03%
# Transaction 4489: Fraud Probability: 52.93%
# Transaction 4490: Fraud Probability: 39.34%
# Transaction 4491: Fraud Probability: 45.89%
# Transaction 4492: Fraud Probability: 17.77%
# Transaction 4493: Fraud Probability: 47.57%
# Transaction 4494: Fraud Probability: 43.92%
# Transaction 4495: Fraud Probability: 59.27%
# Transaction 4496: Fraud Probability: 48.69%
# Transaction 4497: Fraud Probability: 49.74%
# Transaction 4498: Fraud Probability: 51.67%
# Transaction 4499: Fraud Probability: 58.15%
# Transaction 4500: Fraud Probability: 69.89%
# Transaction 4501: Fraud Probability: 60.29%
# Transaction 4502: Fraud Probability: 66.53%
# Transaction 4503: Fraud Probability: 59.40%
# Transaction 4504: Fraud Probability: 51.11%
# Transaction 4505: Fraud Probability: 47.42%
# Transaction 4506: Fraud Probability: 43.54%
# Transaction 4507: Fraud Probability: 59.22%
# Transaction 4508: Fraud Probability: 44.87%
# Transaction 4509: Fraud Probability: 51.06%
# Transaction 4510: Fraud Probability: 64.84%
# Transaction 4511: Fraud Probability: 63.25%
# Transaction 4512: Fraud Probability: 46.91%
# Transaction 4513: Fraud Probability: 54.80%
# Transaction 4514: Fraud Probability: 67.02%
# Transaction 4515: Fraud Probability: 59.95%
# Transaction 4516: Fraud Probability: 63.00%
# Transaction 4517: Fraud Probability: 38.88%
# Transaction 4518: Fraud Probability: 56.30%
# Transaction 4519: Fraud Probability: 59.74%
# Transaction 4520: Fraud Probability: 68.33%
# Transaction 4521: Fraud Probability: 59.92%
# Transaction 4522: Fraud Probability: 54.43%
# Transaction 4523: Fraud Probability: 47.48%
# Transaction 4524: Fraud Probability: 46.72%
# Transaction 4525: Fraud Probability: 51.15%
# Transaction 4526: Fraud Probability: 56.92%
# Transaction 4527: Fraud Probability: 49.66%
# Transaction 4528: Fraud Probability: 52.30%
# Transaction 4529: Fraud Probability: 55.94%
# Transaction 4530: Fraud Probability: 56.45%
# Transaction 4531: Fraud Probability: 49.32%
# Transaction 4532: Fraud Probability: 47.90%
# Transaction 4533: Fraud Probability: 51.82%
# Transaction 4534: Fraud Probability: 64.87%
# Transaction 4535: Fraud Probability: 47.50%
# Transaction 4536: Fraud Probability: 53.50%
# Transaction 4537: Fraud Probability: 53.66%
# Transaction 4538: Fraud Probability: 52.84%
# Transaction 4539: Fraud Probability: 60.08%
# Transaction 4540: Fraud Probability: 57.09%
# Transaction 4541: Fraud Probability: 64.34%
# Transaction 4542: Fraud Probability: 58.74%
# Transaction 4543: Fraud Probability: 62.88%
# Transaction 4544: Fraud Probability: 61.27%
# Transaction 4545: Fraud Probability: 52.24%
# Transaction 4546: Fraud Probability: 53.52%
# Transaction 4547: Fraud Probability: 71.96%
# Transaction 4548: Fraud Probability: 55.20%
# Transaction 4549: Fraud Probability: 46.93%
# Transaction 4550: Fraud Probability: 54.86%
# Transaction 4551: Fraud Probability: 48.72%
# Transaction 4552: Fraud Probability: 62.51%
# Transaction 4553: Fraud Probability: 60.90%
# Transaction 4554: Fraud Probability: 59.44%
# Transaction 4555: Fraud Probability: 33.79%
# Transaction 4556: Fraud Probability: 50.50%
# Transaction 4557: Fraud Probability: 70.64%
# Transaction 4558: Fraud Probability: 53.55%
# Transaction 4559: Fraud Probability: 64.72%
# Transaction 4560: Fraud Probability: 53.56%
# Transaction 4561: Fraud Probability: 64.12%
# Transaction 4562: Fraud Probability: 66.34%
# Transaction 4563: Fraud Probability: 55.30%
# Transaction 4564: Fraud Probability: 55.61%
# Transaction 4565: Fraud Probability: 62.63%
# Transaction 4566: Fraud Probability: 58.56%
# Transaction 4567: Fraud Probability: 44.19%
# Transaction 4568: Fraud Probability: 31.93%
# Transaction 4569: Fraud Probability: 29.39%
# Transaction 4570: Fraud Probability: 54.13%
# Transaction 4571: Fraud Probability: 59.91%
# Transaction 4572: Fraud Probability: 51.88%
# Transaction 4573: Fraud Probability: 61.32%
# Transaction 4574: Fraud Probability: 57.84%
# Transaction 4575: Fraud Probability: 58.61%
# Transaction 4576: Fraud Probability: 58.01%
# Transaction 4577: Fraud Probability: 53.86%
# Transaction 4578: Fraud Probability: 55.59%
# Transaction 4579: Fraud Probability: 63.18%
# Transaction 4580: Fraud Probability: 55.99%
# Transaction 4581: Fraud Probability: 71.64%
# Transaction 4582: Fraud Probability: 50.03%
# Transaction 4583: Fraud Probability: 43.77%
# Transaction 4584: Fraud Probability: 61.16%
# Transaction 4585: Fraud Probability: 60.66%
# Transaction 4586: Fraud Probability: 14.42%
# Transaction 4587: Fraud Probability: 54.57%
# Transaction 4588: Fraud Probability: 62.43%
# Transaction 4589: Fraud Probability: 50.71%
# Transaction 4590: Fraud Probability: 50.03%
# Transaction 4591: Fraud Probability: 34.10%
# Transaction 4592: Fraud Probability: 68.06%
# Transaction 4593: Fraud Probability: 38.28%
# Transaction 4594: Fraud Probability: 55.44%
# Transaction 4595: Fraud Probability: 45.59%
# Transaction 4596: Fraud Probability: 28.98%
# Transaction 4597: Fraud Probability: 53.09%
# Transaction 4598: Fraud Probability: 57.80%
# Transaction 4599: Fraud Probability: 64.62%
# Transaction 4600: Fraud Probability: 51.10%
# Transaction 4601: Fraud Probability: 42.88%
# Transaction 4602: Fraud Probability: 55.16%
# Transaction 4603: Fraud Probability: 55.26%
# Transaction 4604: Fraud Probability: 57.79%
# Transaction 4605: Fraud Probability: 39.90%
# Transaction 4606: Fraud Probability: 68.96%
# Transaction 4607: Fraud Probability: 57.06%
# Transaction 4608: Fraud Probability: 54.96%
# Transaction 4609: Fraud Probability: 59.84%
# Transaction 4610: Fraud Probability: 63.06%
# Transaction 4611: Fraud Probability: 72.55%
# Transaction 4612: Fraud Probability: 41.20%
# Transaction 4613: Fraud Probability: 70.89%
# Transaction 4614: Fraud Probability: 61.79%
# Transaction 4615: Fraud Probability: 61.93%
# Transaction 4616: Fraud Probability: 44.58%
# Transaction 4617: Fraud Probability: 66.94%
# Transaction 4618: Fraud Probability: 66.87%
# Transaction 4619: Fraud Probability: 60.20%
# Transaction 4620: Fraud Probability: 57.99%
# Transaction 4621: Fraud Probability: 56.92%
# Transaction 4622: Fraud Probability: 48.48%
# Transaction 4623: Fraud Probability: 48.73%
# Transaction 4624: Fraud Probability: 54.02%
# Transaction 4625: Fraud Probability: 69.69%
# Transaction 4626: Fraud Probability: 54.58%
# Transaction 4627: Fraud Probability: 49.30%
# Transaction 4628: Fraud Probability: 62.78%
# Transaction 4629: Fraud Probability: 53.63%
# Transaction 4630: Fraud Probability: 60.04%
# Transaction 4631: Fraud Probability: 40.90%
# Transaction 4632: Fraud Probability: 58.10%
# Transaction 4633: Fraud Probability: 57.58%
# Transaction 4634: Fraud Probability: 53.99%
# Transaction 4635: Fraud Probability: 68.89%
# Transaction 4636: Fraud Probability: 55.32%
# Transaction 4637: Fraud Probability: 60.22%
# Transaction 4638: Fraud Probability: 64.79%
# Transaction 4639: Fraud Probability: 52.88%
# Transaction 4640: Fraud Probability: 61.24%
# Transaction 4641: Fraud Probability: 52.88%
# Transaction 4642: Fraud Probability: 56.22%
# Transaction 4643: Fraud Probability: 54.55%
# Transaction 4644: Fraud Probability: 52.97%
# Transaction 4645: Fraud Probability: 59.84%
# Transaction 4646: Fraud Probability: 36.14%
# Transaction 4647: Fraud Probability: 41.53%
# Transaction 4648: Fraud Probability: 53.40%
# Transaction 4649: Fraud Probability: 51.45%
# Transaction 4650: Fraud Probability: 46.04%
# Transaction 4651: Fraud Probability: 65.86%
# Transaction 4652: Fraud Probability: 42.04%
# Transaction 4653: Fraud Probability: 49.99%
# Transaction 4654: Fraud Probability: 44.02%
# Transaction 4655: Fraud Probability: 59.48%
# Transaction 4656: Fraud Probability: 59.47%
# Transaction 4657: Fraud Probability: 60.02%
# Transaction 4658: Fraud Probability: 47.42%
# Transaction 4659: Fraud Probability: 44.56%
# Transaction 4660: Fraud Probability: 51.79%
# Transaction 4661: Fraud Probability: 43.94%
# Transaction 4662: Fraud Probability: 53.44%
# Transaction 4663: Fraud Probability: 43.35%
# Transaction 4664: Fraud Probability: 50.33%
# Transaction 4665: Fraud Probability: 39.35%
# Transaction 4666: Fraud Probability: 55.12%
# Transaction 4667: Fraud Probability: 55.24%
# Transaction 4668: Fraud Probability: 50.28%
# Transaction 4669: Fraud Probability: 68.25%
# Transaction 4670: Fraud Probability: 63.16%
# Transaction 4671: Fraud Probability: 59.64%
# Transaction 4672: Fraud Probability: 54.57%
# Transaction 4673: Fraud Probability: 49.27%
# Transaction 4674: Fraud Probability: 66.73%
# Transaction 4675: Fraud Probability: 63.59%
# Transaction 4676: Fraud Probability: 45.26%
# Transaction 4677: Fraud Probability: 39.23%
# Transaction 4678: Fraud Probability: 57.07%
# Transaction 4679: Fraud Probability: 74.33%
# Transaction 4680: Fraud Probability: 71.16%
# Transaction 4681: Fraud Probability: 57.20%
# Transaction 4682: Fraud Probability: 66.44%
# Transaction 4683: Fraud Probability: 71.68%
# Transaction 4684: Fraud Probability: 62.43%
# Transaction 4685: Fraud Probability: 54.06%
# Transaction 4686: Fraud Probability: 64.71%
# Transaction 4687: Fraud Probability: 59.05%
# Transaction 4688: Fraud Probability: 59.94%
# Transaction 4689: Fraud Probability: 49.92%
# Transaction 4690: Fraud Probability: 65.95%
# Transaction 4691: Fraud Probability: 51.47%
# Transaction 4692: Fraud Probability: 63.81%
# Transaction 4693: Fraud Probability: 59.98%
# Transaction 4694: Fraud Probability: 55.76%
# Transaction 4695: Fraud Probability: 41.14%
# Transaction 4696: Fraud Probability: 52.37%
# Transaction 4697: Fraud Probability: 57.87%
# Transaction 4698: Fraud Probability: 46.16%
# Transaction 4699: Fraud Probability: 64.19%
# Transaction 4700: Fraud Probability: 50.60%
# Transaction 4701: Fraud Probability: 55.32%
# Transaction 4702: Fraud Probability: 54.08%
# Transaction 4703: Fraud Probability: 58.72%
# Transaction 4704: Fraud Probability: 61.05%
# Transaction 4705: Fraud Probability: 53.81%
# Transaction 4706: Fraud Probability: 71.00%
# Transaction 4707: Fraud Probability: 65.17%
# Transaction 4708: Fraud Probability: 59.85%
# Transaction 4709: Fraud Probability: 61.78%
# Transaction 4710: Fraud Probability: 61.88%
# Transaction 4711: Fraud Probability: 53.39%
# Transaction 4712: Fraud Probability: 54.68%
# Transaction 4713: Fraud Probability: 59.60%
# Transaction 4714: Fraud Probability: 51.28%
# Transaction 4715: Fraud Probability: 43.77%
# Transaction 4716: Fraud Probability: 61.33%
# Transaction 4717: Fraud Probability: 56.02%
# Transaction 4718: Fraud Probability: 61.55%
# Transaction 4719: Fraud Probability: 72.62%
# Transaction 4720: Fraud Probability: 60.22%
# Transaction 4721: Fraud Probability: 63.49%
# Transaction 4722: Fraud Probability: 39.76%
# Transaction 4723: Fraud Probability: 59.92%
# Transaction 4724: Fraud Probability: 48.17%
# Transaction 4725: Fraud Probability: 50.34%
# Transaction 4726: Fraud Probability: 61.22%
# Transaction 4727: Fraud Probability: 63.02%
# Transaction 4728: Fraud Probability: 54.10%
# Transaction 4729: Fraud Probability: 47.25%
# Transaction 4730: Fraud Probability: 70.17%
# Transaction 4731: Fraud Probability: 44.12%
# Transaction 4732: Fraud Probability: 55.46%
# Transaction 4733: Fraud Probability: 45.62%
# Transaction 4734: Fraud Probability: 52.66%
# Transaction 4735: Fraud Probability: 58.91%
# Transaction 4736: Fraud Probability: 30.34%
# Transaction 4737: Fraud Probability: 59.79%
# Transaction 4738: Fraud Probability: 61.17%
# Transaction 4739: Fraud Probability: 53.18%
# Transaction 4740: Fraud Probability: 53.96%
# Transaction 4741: Fraud Probability: 45.68%
# Transaction 4742: Fraud Probability: 35.54%
# Transaction 4743: Fraud Probability: 45.94%
# Transaction 4744: Fraud Probability: 58.73%
# Transaction 4745: Fraud Probability: 51.00%
# Transaction 4746: Fraud Probability: 53.85%
# Transaction 4747: Fraud Probability: 45.85%
# Transaction 4748: Fraud Probability: 55.45%
# Transaction 4749: Fraud Probability: 58.05%
